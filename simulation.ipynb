# %% [markdown]
# # Causal Plan
#
# Tooling to create, learn and integrate causality into production planning.
#
# ### How to run?
#
# 1. Create and activate .venv
#     ```
#     python3 -m venv .venv
#     source .venv/bin/activate
#     ```
# 2. Install requirements via pip
#     ```
#     pip install -r requirements.txt
#     ```
# 3. Execute this notebook

# %% [markdown]
# ### 1. Start by call causal network and build three kinds of Production Plan
#
# - causal
# - non-causal
# - average non causal

# %%
from causal.causal_model_causal_non_causal import CausalModelCBN
from causal.causal_model import CausalModel
from plan.GifflerThompson import GifflerThompson
from factory.Operation import Operation
from generators.jobs_data_generator import JobsDataGenerator
from plan.PriorityRules import calculate_dynamic_priority, calculate_fcfs_priority

# Beispielhafte Datenstruktur
# Produkt, Arbeitsgang, Maschinengruppe, Tool, geplante Dauer, Nachfolger
template_jobs_data = [
    ['p1', 1, 'a1', 1, 30, 4],
    ['p1', 2, 'a2', 1, 45, 4],
    ['p1', 3, 'a1', 2, 15, 4],
    ['p1', 4, 'a3', 1, 15, -1],
    ['p2', 1, 'a1', 1, 15, 3],
    ['p2', 2, 'a4', 2, 45, 3],
    ['p2', 3, 'a3', 2, 15, 5],
    ['p2', 4, 'a2', 1, 30, 5],
    ['p2', 5, 'a4', 1, 15, -1]
]

generator = JobsDataGenerator(template_jobs_data)
num_instances = 15  # Number of new instances to generate
relation = {'p1': 0.5, 'p2': 0.5}  # Relation of each product type

jobs_data = generator.generate_jobs_data(num_instances, relation)

# Maschinenpools definieren
# id, number, tools 
machine_pools_data = [
    ['a1', 1, [1,2,3]],
    ['a2', 1, [1,2,3]],
    ['a3', 1, [1,2,3]],
    ['a4', 1, [1,2,3]],
]

# Konvertiere die jobs_data in Operation-Objekte
operations_causal = [Operation(*data) for data in jobs_data]
operations_non_causal = [Operation(*data) for data in jobs_data]
operations_non_avg_causal = [Operation(*data) for data in jobs_data]

# causal model
observed_data = []

csv_file = 'data/observed_data.csv'
model = CausalModelCBN(csv_file)
#model = CausalModel(csv_file=csv_file)
# Causal model for simulation
# define an inference rule    
def simulation_inference(operation: Operation, tool) -> int:
 
    # 1. Preperation step
    # used for create/modify properties beforehand
    #has_lots_operations = len(operation.predecessor_operations) > 1
    #is_shorter_than_15 =  operation.plan_duration < 15
    #filtered_pools = [pool for pool in sim.pools.values() if pool.group == operation.machine.group and pool.id != operation.machine.id]
    #one_working = any(pool.current_operation is not None for pool in filtered_pools) 
    
    # 2. Infer step
    inferenced_variables = model.infer_duration(True, operation, tool)

    # 3. Calculation step
    new_duration = round(operation.duration * inferenced_variables['delay'],0)
    
    # Save for causal learning
    observed_data.append([tool, inferenced_variables['machine_status'], inferenced_variables['pre_processing'], inferenced_variables['delay']])

    print(f"Operation duration was: {operation.duration} and has been changed to {new_duration}")
    return new_duration

# Causal model for planning
# define an inference rule
def plan_inference(operation: Operation, tool) -> int:
        
    # 2. Infer step
    inferenced_variables = model.infer_duration(False, operation, tool)

    new_duration = round(operation.duration * inferenced_variables['delay'],0)

    return new_duration

# Causal model for planning
# define an inference rule
def plan_inference_non(operation: Operation, tool) -> int:
    return operation.duration

def plan_inference_with_avg_duration(operation: Operation, tool) -> int:
    return operation.duration * model.avg_duration

# Case 1: Causal Learned Model
gt = GifflerThompson(calculate_fcfs_priority, plan_inference)
gt_causal_schedule = gt.giffen_thompson(operations_causal, machine_pools_data)

# Case 2: Non-Causal Model
non_causal = GifflerThompson(calculate_fcfs_priority, plan_inference_non)
gt_non_causal_schedule = non_causal.giffen_thompson(operations_non_causal, machine_pools_data)

# Case 3: Model with average duration delay
non_avg_causal = GifflerThompson(calculate_fcfs_priority, plan_inference_with_avg_duration)
gt_non_avg_causal_schedule = non_avg_causal.giffen_thompson(operations_non_avg_causal, machine_pools_data)
# Out:
# Set edges by user
# Testing combination: Algorithm=exhaustive, Score=K2
# Lerne Modell mit exhaustive-Algorithmus und K2-Score
# Successful combination: Algorithm=exhaustive, Score=K2
# Anzahl der erfolgreich gelernten Modelle:  1

# %% [markdown]
# ###  2. Execute Simulation based on non causal Production Plan

# %%
from simulation.Simulator import Simulator
from simulation.Monitoring.BasicMonitor import monitorResource
from functools import partial

# array to store monitored data
data = []

# resource monitor [pre , post] execution
monitor = [None, partial(monitorResource, data)]

sim = Simulator(machine_pools_data
                , operations_non_causal
                , monitor
                , simulation_inference)

sim.env.run(12000)
# Out:
# 0
# 0
# 45
# 0
# 60
# 15
# 75
# 120
# 30
# 135
# 30
# 150
# 195
# 60
# 210
# 45
# 90
# 75
# 210
# 90
# 135
# 120
# 225
# 135
# 225
# 270
# 180
# 285
# 150
# 210
# 180
# 285
# 195
# 255
# 225
# 300
# 240
# 300
# 270
# 345
# 285
# 345
# 315
# 390
# 330
# 390
# 360
# 435
# 375
# 300
# 450
# 435
# 465
# 390
# 465
# 420
# 510
# 435
# 510
# 465
# 555
# 480
# 555
# 510
# 600
# 0, job: p3, operation_id: 1, getting resource
# 0, job: p3, operation_id: 2, getting resource
# 0, job: p3, operation_id: 4, getting resource
# 0, job: p3, operation_id: 1, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 0, job: p3, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 0, job: p3, operation_id: 4, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 15, job: p4, operation_id: 1, getting resource
# 18.0, job: p3, operation_id: 1, finished operation
# 18.0, job: p4, operation_id: 1, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 30.0, job: p3, operation_id: 4, finished operation
# 30, job: p4, operation_id: 4, getting resource
# 30, job: p5, operation_id: 1, getting resource
# 30, job: p4, operation_id: 4, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 33.0, job: p4, operation_id: 1, finished operation
# 33.0, job: p5, operation_id: 1, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 45.0, job: p3, operation_id: 2, finished operation
# 45, job: p6, operation_id: 1, getting resource
# 45.0, job: p3, operation_id: 3, getting resource
# 45.0, job: p3, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 48.0, job: p5, operation_id: 1, finished operation
# 48.0, job: p6, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 36.0
# 60.0, job: p4, operation_id: 4, finished operation
# 60.0, job: p3, operation_id: 3, finished operation
# 60, job: p5, operation_id: 4, getting resource
# 60, job: p5, operation_id: 4, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 60.0, job: p3, operation_id: 5, getting resource
# 60.0, job: p3, operation_id: 5, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 75, job: p4, operation_id: 2, getting resource
# 75, job: p6, operation_id: 3, getting resource
# 78.0, job: p3, operation_id: 5, finished operation
# 78.0, job: p4, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 84.0, job: p6, operation_id: 1, finished operation
# 84.0, job: p6, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 90.0, job: p5, operation_id: 4, finished operation
# 90, job: p6, operation_id: 2, getting resource
# 90, job: p7, operation_id: 1, getting resource
# 90, job: p6, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 99.0, job: p6, operation_id: 3, finished operation
# 99.0, job: p7, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 120, job: p7, operation_id: 3, getting resource
# 123.0, job: p4, operation_id: 2, finished operation
# 123.0, job: p4, operation_id: 3, getting resource
# 123.0, job: p4, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 129.0, job: p7, operation_id: 1, finished operation
# 129.0, job: p7, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 135, job: p7, operation_id: 2, getting resource
# 135, job: p8, operation_id: 1, getting resource
# 141.0, job: p4, operation_id: 3, finished operation
# 141.0, job: p4, operation_id: 5, getting resource
# 141.0, job: p4, operation_id: 5, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 144.0, job: p6, operation_id: 2, finished operation
# 144.0, job: p7, operation_id: 3, finished operation
# 144.0, job: p7, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 144.0, job: p8, operation_id: 1, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 150, job: p5, operation_id: 2, getting resource
# 150, job: p9, operation_id: 1, getting resource
# 159.0, job: p4, operation_id: 5, finished operation
# 159.0, job: p8, operation_id: 1, finished operation
# 159.0, job: p5, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 159.0, job: p9, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 180, job: p8, operation_id: 4, getting resource
# 180, job: p9, operation_id: 3, getting resource
# 189.0, job: p7, operation_id: 2, finished operation
# 189.0, job: p9, operation_id: 1, finished operation
# 189.0, job: p8, operation_id: 4, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 189.0, job: p9, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 195, job: p10, operation_id: 1, getting resource
# 204.0, job: p5, operation_id: 2, finished operation
# 204.0, job: p5, operation_id: 3, getting resource
# 204.0, job: p5, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 207.0, job: p9, operation_id: 3, finished operation
# 207.0, job: p10, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 210, job: p6, operation_id: 4, getting resource
# 210, job: p9, operation_id: 2, getting resource
# 219.0, job: p8, operation_id: 4, finished operation
# 219.0, job: p9, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 222.0, job: p5, operation_id: 3, finished operation
# 222.0, job: p6, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 222.0, job: p5, operation_id: 5, getting resource
# 222.0, job: p5, operation_id: 5, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 225, job: p7, operation_id: 4, getting resource
# 225, job: p8, operation_id: 2, getting resource
# 225, job: p10, operation_id: 3, getting resource
# 237.0, job: p10, operation_id: 1, finished operation
# 237.0, job: p6, operation_id: 4, finished operation
# 237.0, job: p5, operation_id: 5, finished operation
# 237.0, job: p10, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 237.0, job: p7, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 237.0, job: p8, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 240, job: p11, operation_id: 1, getting resource
# 252.0, job: p7, operation_id: 4, finished operation
# 255.0, job: p10, operation_id: 3, finished operation
# 255, job: p10, operation_id: 2, getting resource
# 255.0, job: p11, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 270, job: p11, operation_id: 3, getting resource
# 273.0, job: p9, operation_id: 2, finished operation
# 273.0, job: p10, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 285.0, job: p11, operation_id: 1, finished operation
# 285, job: p9, operation_id: 4, getting resource
# 285, job: p12, operation_id: 1, getting resource
# 285, job: p9, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 285, job: p11, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 291.0, job: p8, operation_id: 2, finished operation
# 291.0, job: p8, operation_id: 3, getting resource
# 300, job: p11, operation_id: 2, getting resource
# 300, job: p14, operation_id: 2, getting resource
# 300, job: p14, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 303.0, job: p9, operation_id: 4, finished operation
# 303.0, job: p11, operation_id: 3, finished operation
# 303.0, job: p8, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 303.0, job: p12, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 36.0
# 315, job: p12, operation_id: 3, getting resource
# 318.0, job: p8, operation_id: 3, finished operation
# 318.0, job: p8, operation_id: 5, getting resource
# 327.0, job: p10, operation_id: 2, finished operation
# 327.0, job: p11, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 327.0, job: p10, operation_id: 4, getting resource
# 327.0, job: p10, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 330, job: p13, operation_id: 1, getting resource
# 339.0, job: p12, operation_id: 1, finished operation
# 339.0, job: p12, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 342.0, job: p10, operation_id: 4, finished operation
# 345.0, job: p14, operation_id: 2, finished operation
# 345, job: p12, operation_id: 2, getting resource
# 345.0, job: p8, operation_id: 5, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 354.0, job: p12, operation_id: 3, finished operation
# 354.0, job: p13, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 360.0, job: p8, operation_id: 5, finished operation
# 360, job: p13, operation_id: 3, getting resource
# 372.0, job: p11, operation_id: 2, finished operation
# 372.0, job: p12, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 372.0, job: p11, operation_id: 4, getting resource
# 372.0, job: p11, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 375, job: p14, operation_id: 1, getting resource
# 384.0, job: p13, operation_id: 1, finished operation
# 384.0, job: p13, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 387.0, job: p11, operation_id: 4, finished operation
# 390, job: p13, operation_id: 2, getting resource
# 390, job: p15, operation_id: 1, getting resource
# 402.0, job: p13, operation_id: 3, finished operation
# 402.0, job: p14, operation_id: 1, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 417.0, job: p12, operation_id: 2, finished operation
# 417.0, job: p14, operation_id: 1, finished operation
# 417.0, job: p13, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 45.0
# 417.0, job: p12, operation_id: 4, getting resource
# 417.0, job: p15, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 417.0, job: p12, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 420, job: p15, operation_id: 3, getting resource
# 432.0, job: p12, operation_id: 4, finished operation
# 435, job: p14, operation_id: 4, getting resource
# 435, job: p16, operation_id: 1, getting resource
# 447.0, job: p15, operation_id: 1, finished operation
# 447.0, job: p15, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 450, job: p14, operation_id: 3, getting resource
# 450, job: p14, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 462.0, job: p13, operation_id: 2, finished operation
# 462.0, job: p15, operation_id: 3, finished operation
# 462.0, job: p14, operation_id: 4, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 462.0, job: p13, operation_id: 4, getting resource
# 462.0, job: p16, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 36.0
# 465, job: p15, operation_id: 2, getting resource
# 465, job: p16, operation_id: 3, getting resource
# 468.0, job: p14, operation_id: 3, finished operation
# 468.0, job: p13, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 480, job: p17, operation_id: 1, getting resource
# 486.0, job: p13, operation_id: 4, finished operation
# 492.0, job: p14, operation_id: 4, finished operation
# 492.0, job: p15, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 492.0, job: p14, operation_id: 5, getting resource
# 492.0, job: p14, operation_id: 5, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 498.0, job: p16, operation_id: 1, finished operation
# 498.0, job: p16, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 507.0, job: p14, operation_id: 5, finished operation
# 510, job: p16, operation_id: 2, getting resource
# 510, job: p17, operation_id: 3, getting resource
# 513.0, job: p16, operation_id: 3, finished operation
# 513.0, job: p17, operation_id: 1, starting operation
# Operation duration was: 30 and has been changed to 30.0
# 543.0, job: p17, operation_id: 1, finished operation
# 543.0, job: p17, operation_id: 3, starting operation
# Operation duration was: 15 and has been changed to 18.0
# 546.0, job: p15, operation_id: 2, finished operation
# 546.0, job: p16, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 546.0, job: p15, operation_id: 4, getting resource
# 546.0, job: p15, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 555, job: p17, operation_id: 2, getting resource
# 561.0, job: p17, operation_id: 3, finished operation
# 561.0, job: p15, operation_id: 4, finished operation
# 600.0, job: p16, operation_id: 2, finished operation
# 600.0, job: p17, operation_id: 2, starting operation
# Operation duration was: 45 and has been changed to 54.0
# 600.0, job: p16, operation_id: 4, getting resource
# 600.0, job: p16, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 615.0, job: p16, operation_id: 4, finished operation
# 654.0, job: p17, operation_id: 2, finished operation
# 654.0, job: p17, operation_id: 4, getting resource
# 654.0, job: p17, operation_id: 4, starting operation
# Operation duration was: 15 and has been changed to 15.0
# 669.0, job: p17, operation_id: 4, finished operation

# %% [markdown]
# ### 3. Metrics to compare the plan

# %%
import pandas as pd

def calculate_makespan(df_schedule, schedule_name):
    # Convert the list of operation objects to a DataFrame
    

    # Calculate start and end times for each job
    grouped_schedule = df_schedule.groupby('job_id').agg({'start_time': 'min', 'end_time': 'max'})

    # Calculate the makespan for each job
    grouped_schedule['makespan'] = grouped_schedule['end_time'] - grouped_schedule['start_time']

    # Calculate the average makespan across all jobs
    average_makespan = grouped_schedule['makespan'].mean()

    # Output the results with the schedule name
    print(f"{schedule_name} | {average_makespan} time units")

print(f"Average makespan across all products: ")
# Example usage with named schedules
calculate_makespan(pd.DataFrame([op.to_dict() for op in gt_non_causal_schedule]), 'NonCausal')
calculate_makespan(pd.DataFrame([op.to_dict() for op in gt_causal_schedule]), 'Causal')
calculate_makespan(pd.DataFrame([op.to_dict() for op in gt_non_avg_causal_schedule]), 'NonCausal with AVG')
calculate_makespan(pd.DataFrame([op.to_dict_sim() for op in sim.schedule]), 'Sim')
# Out:
# Average makespan across all products:
# NonCausal | 141.0 time units
# Causal | 152.0 time units
# NonCausal with AVG | 157.51714285714291 time units
# Sim | 154.2 time units

# %%
import math

truth_sim = pd.DataFrame([op.to_dict_sim() for op in sim.schedule])
truth_causal = pd.DataFrame([op.to_dict() for op in gt_causal_schedule])

combined_df = pd.merge(truth_sim, truth_causal, on=['job_id', 'operation_id'], how='outer')

#trouth_sim['diff'] = trouth_sim['duration'] - trouth_sim['plan_duration']
#trouth_causal['diff'] = trouth_causal['plan_duration'] - trouth_causal['duration']
#trouth_sim['sim_causal_dif'] = trouth_causal['plan_duration'] - trouth_sim['duration']


combined_df['diff_sim_truth'] = combined_df['duration_x'] - combined_df['plan_duration_x']
combined_df['diff_causal_truth'] = combined_df['plan_duration_y'] - combined_df['duration_y']
combined_df['diff_causal_sim'] = combined_df['duration_x'] - combined_df['plan_duration_y'] 
combined_df[['duration_x','plan_duration_x', 'diff_sim_truth', 'diff_sim_truth', 'diff_causal_sim']].describe()
# combined_df[combined_df['diff_causal_sim'] > 0].head(1000)
# Out:
#        duration_x  plan_duration_x  diff_sim_truth  diff_sim_truth  \
# count   65.000000        65.000000       65.000000       65.000000
# mean    27.230769        25.384615        1.846154        1.846154
# std     13.842608        12.415580        2.985542        2.985542
# min     15.000000        15.000000        0.000000        0.000000
# 25%     15.000000        15.000000        0.000000        0.000000
# 50%     18.000000        15.000000        0.000000        0.000000
# 75%     36.000000        30.000000        3.000000        3.000000
# max     54.000000        45.000000        9.000000        9.000000
#
#        diff_causal_sim
# count        65.000000
# mean         -0.876923
# std           3.663621
# min          -9.000000
# 25%          -3.000000
# 50%           0.000000
# 75%           0.000000
# max           9.000000

# %% [markdown]
# ### 4. Save the observed data for causal learning (required for step causal plan)

# %%
df_observed_data = pd.DataFrame(observed_data, columns=['previous_machine_pause' , 'machine_status', 'pre_processing', 'delay'])
df_observed_data.to_csv(csv_file)

# %% [markdown]
# ### 5. Evaulation

# %% [markdown]
# #### 5.1 Simulation (with predefiend model)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math

# Daten in ein DataFrame konvertieren
df = pd.DataFrame([op.to_dict_sim() for op in sim.schedule])

size_height = math.ceil(df["machine"].count().itemsize / 3)
# Gantt-Diagramm erstellen
fig, ax = plt.subplots(figsize=(24, size_height))

# Maschinen als y-Werte für die Balken
machines = df['machine'].unique()
machine_to_y = {machine: i for i, machine in enumerate(machines)}

# Erstelle eine Colormap für die job_ids
unique_jobs = df['job_id'].unique()
job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}

# Iteriere über jede Zeile des DataFrames
for i, row in df.iterrows():
    start = row['start_time']
    duration = row['duration']
    job_id = row['job_id']
    task_id = row['operation_id']
    machine = row['machine']
    label = f'{job_id} {task_id}'

    # Verwende die Farbe für den entsprechenden job_id
    color = job_colors[job_id]

    # Stelle die Aufgabe als Balken im Diagramm dar
    ax.barh(y=machine_to_y[machine], left=start, width=duration, height=0.8, align='center', color=color, edgecolor='black')
    
    # Text in den Balken einfügen (optional, falls du das möchtest)
    # ax.text(x=start + duration / 2, y=machine_to_y[machine], s=label, va='center', ha='center', color='black')

# Diagramm formatieren
ax.set_xlabel('Time')
ax.set_yticks(list(machine_to_y.values()))
ax.set_yticklabels(list(machine_to_y.keys()))
ax.set_title('Gantt Chart')
max_time = df['start_time'].max() + df['duration'].max()  # Determine max time to cover full range
ax.set_xticks(range(0, math.ceil(max_time) + 1, 5))

# Grid anzeigen
ax.grid(True)

# Diagramm anzeigen
plt.show()
# Out:
# /tmp/ipykernel_409995/1685830134.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}

# %% [markdown]
# #### 5.2 Plan without causal model

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math

# Daten in ein DataFrame konvertieren
df = pd.DataFrame([p.to_dict() for p in gt_non_causal_schedule])

size_height = math.ceil(df["machine"].count().itemsize / 3)
# Gantt-Diagramm erstellen
fig, ax = plt.subplots(figsize=(24, size_height))

# Maschinen als y-Werte für die Balken
machines = df['machine'].unique()
machine_to_y = {machine: i for i, machine in enumerate(machines)}

unique_jobs = df['job_id'].unique()
job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}

# Iteriere über jede Zeile des DataFrames
for i, row in df.iterrows():
    start = row['start_time']
    duration = row['plan_duration']
    job_id = row['job_id']
    task_id = row['operation_id']
    machine = row['machine']
    label = f'{job_id} {task_id}'

    # Verwende die Farbe für den entsprechenden job_id
    color = job_colors[job_id]

    # Stelle die Aufgabe als Balken im Diagramm dar
    ax.barh(y=machine_to_y[machine], left=start, width=duration, height=0.8, align='center', color=color, edgecolor='black')
    
    # Text in den Balken einfügen
    #ax.text(x=start + duration / 2, y=machine_to_y[machine], s=label, va='center', ha='center', color='black')

# Diagramm formatieren
ax.set_xlabel('Time')
ax.set_yticks(list(machine_to_y.values()))
ax.set_yticklabels(list(machine_to_y.keys()))
ax.set_title('Gantt Chart')
max_time = df['start_time'].max() + df['duration'].max()  # Determine max time to cover full range
ax.set_xticks(range(0, math.ceil(max_time) + 1, 5))
# Grid anzeigen
ax.grid(True)

# Legende entfernen, da sie nicht mehr notwendig ist
# Handles und Labels der Legende deduplizieren
# handles, labels = plt.gca().get_legend_handles_labels()
# by_label = dict(zip(labels, handles))
# plt.legend(by_label.values(), by_label.keys())

# Diagramm anzeigen
plt.show()
# Out:
# /tmp/ipykernel_409995/1553617269.py:17: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}

# %% [markdown]
# #### 5.3 Plan with causal model

# %%
import matplotlib.pyplot as plt
import pandas as pd
import math

# Daten in ein DataFrame konvertieren
df = pd.DataFrame([p.to_dict() for p in gt_causal_schedule])

size_height = math.ceil(df["machine"].count().itemsize / 3)
# Gantt-Diagramm erstellen
fig, ax = plt.subplots(figsize=(24, size_height))

# Maschinen als y-Werte für die Balken
machines = df['machine'].unique()
machine_to_y = {machine: i for i, machine in enumerate(machines)}

# Erstelle eine Colormap für die job_ids
unique_jobs = df['job_id'].unique()
job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}

# Iteriere über jede Zeile des DataFrames
for i, row in df.iterrows():
    start = row['start_time']
    duration = row['plan_duration']
    job_id = row['job_id']
    task_id = row['operation_id']
    machine = row['machine']
    label = f'{job_id} {task_id}'

    # Verwende die Farbe für den entsprechenden job_id
    color = job_colors[job_id]
    # Stelle die Aufgabe als Balken im Diagramm dar
    ax.barh(y=machine_to_y[machine], left=start, width=duration, height=0.8, align='center', color=color, edgecolor='black')
    
    # Text in den Balken einfügen
    #ax.text(x=start + duration / 2, y=machine_to_y[machine], s=label, va='center', ha='center', color='black')

# Diagramm formatieren
ax.set_xlabel('Time')
ax.set_yticks(list(machine_to_y.values()))
ax.set_yticklabels(list(machine_to_y.keys()))
ax.set_title('Gantt Chart')
max_time = df['start_time'].max() + df['duration'].max()  # Determine max time to cover full range
ax.set_xticks(range(0, math.ceil(max_time) + 1, 5))
# Grid anzeigen
ax.grid(True)


# Diagramm anzeigen
plt.show()
# Out:
# /tmp/ipykernel_409995/276026655.py:18: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   job_colors = {job_id: plt.cm.get_cmap('tab20')(i / len(unique_jobs)) for i, job_id in enumerate(unique_jobs)}
